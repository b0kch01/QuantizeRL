# %%
import numpy as np
import torch
import gym
from torch import nn
from torch.nn import functional as F
import matplotlib.pyplot as plt

# %%
def mish(input):
    return input * torch.tanh(F.softplus(input))

class Mish(nn.Module):
    def __init__(self): super().__init__()
    def forward(self, input): return mish(input)

# %%
# helper function to convert numpy arrays to tensors
def t(x): return torch.from_numpy(x).float()

# %%
# Actor module, categorical actions only
class Actor(nn.Module):
    def __init__(self, state_dim, n_actions, activation=nn.Tanh):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(state_dim, 64),
            activation(),
            nn.Linear(64, 64),
            activation(),
            nn.Linear(64, n_actions),
            nn.Softmax()
        )
    
    def forward(self, X):
        return self.model(X)

# %%
# Critic module
class Critic(nn.Module):
    def __init__(self, state_dim, activation=nn.Tanh):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(state_dim, 64),
            activation(),
            nn.Linear(64, 64),
            activation(),
            nn.Linear(64, 1)
        )
    
    def forward(self, X):
        return self.model(X)

# %%
env = gym.make("CartPole-v1")

# %%
# config
state_dim = env.observation_space.shape[0]
n_actions = env.action_space.n
actor = Actor(state_dim, n_actions, activation=Mish)
critic = Critic(state_dim, activation=Mish)
adam_actor = torch.optim.Adam(actor.parameters(), lr=3e-4)
adam_critic = torch.optim.Adam(critic.parameters(), lr=1e-3)

torch.manual_seed(1)

# %%
def clip_grad_norm_(module, max_grad_norm):
    nn.utils.clip_grad_norm_([p for g in module.param_groups for p in g["params"]], max_grad_norm)

def policy_loss(old_log_prob, log_prob, advantage, eps):
    ratio = (log_prob - old_log_prob).exp()
    clipped = torch.clamp(ratio, 1-eps, 1+eps)*advantage
    
    m = torch.min(ratio*advantage, clipped)
    return -m

# %%
episode_rewards = []
gamma = 0.99
eps = 0.2
s = 0
max_grad_norm = 0.5

for i in range(800):
    prev_prob_act = None
    done = False
    total_reward = 0
    state, _ = env.reset()

    while not done:
        s += 1
        probs = actor(t(state))
        dist = torch.distributions.Categorical(probs=probs)
        action = dist.sample()
        prob_act = dist.log_prob(action)
        
        next_state, reward, done, _, info = env.step(action.detach().data.numpy())
        advantage = reward + (1-done)*gamma*critic(t(next_state)) - critic(t(state))
        
        total_reward += reward
        state = next_state
        
        if prev_prob_act:
            actor_loss = policy_loss(prev_prob_act.detach(), prob_act, advantage.detach(), eps)
            adam_actor.zero_grad()
            actor_loss.backward()
            # clip_grad_norm_(adam_actor, max_grad_norm)
            adam_actor.step()

            critic_loss = advantage.pow(2).mean()
            adam_critic.zero_grad()
            critic_loss.backward()
            # clip_grad_norm_(adam_critic, max_grad_norm)
            adam_critic.step()
        
        prev_prob_act = prob_act
    
    print(f"Episode {i+1} finished after {s} steps with total reward {total_reward}")
    episode_rewards.append(total_reward)
# Out:
# /Users/b0kch01/miniconda3/envs/pytorch-m1/lib/python3.10/site-packages/torch/nn/modules/module.py:1518: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self._call_impl(*args, **kwargs)
# Episode 1 finished after 26 steps with total reward 26.0
# Episode 2 finished after 50 steps with total reward 24.0
# Episode 3 finished after 71 steps with total reward 21.0
# Episode 4 finished after 87 steps with total reward 16.0
# Episode 5 finished after 107 steps with total reward 20.0
# Episode 6 finished after 132 steps with total reward 25.0
# Episode 7 finished after 153 steps with total reward 21.0
# Episode 8 finished after 201 steps with total reward 48.0
# Episode 9 finished after 223 steps with total reward 22.0
# Episode 10 finished after 254 steps with total reward 31.0
# Episode 11 finished after 275 steps with total reward 21.0
# Episode 12 finished after 296 steps with total reward 21.0
# Episode 13 finished after 308 steps with total reward 12.0
# Episode 14 finished after 320 steps with total reward 12.0
# Episode 15 finished after 336 steps with total reward 16.0
# Episode 16 finished after 366 steps with total reward 30.0
# Episode 17 finished after 381 steps with total reward 15.0
# Episode 18 finished after 395 steps with total reward 14.0
# Episode 19 finished after 440 steps with total reward 45.0
# Episode 20 finished after 453 steps with total reward 13.0
# Episode 21 finished after 473 steps with total reward 20.0
# Episode 22 finished after 489 steps with total reward 16.0
# Episode 23 finished after 509 steps with total reward 20.0
# Episode 24 finished after 525 steps with total reward 16.0
# Episode 25 finished after 559 steps with total reward 34.0
# Episode 26 finished after 579 steps with total reward 20.0
# Episode 27 finished after 616 steps with total reward 37.0
# Episode 28 finished after 635 steps with total reward 19.0
# Episode 29 finished after 690 steps with total reward 55.0
# Episode 30 finished after 726 steps with total reward 36.0
# Episode 31 finished after 776 steps with total reward 50.0
# Episode 32 finished after 788 steps with total reward 12.0
# Episode 33 finished after 799 steps with total reward 11.0
# Episode 34 finished after 848 steps with total reward 49.0
# Episode 35 finished after 881 steps with total reward 33.0
# Episode 36 finished after 905 steps with total reward 24.0
# Episode 37 finished after 932 steps with total reward 27.0
# Episode 38 finished after 953 steps with total reward 21.0
# Episode 39 finished after 988 steps with total reward 35.0
# Episode 40 finished after 1020 steps with total reward 32.0
# Episode 41 finished after 1047 steps with total reward 27.0
# Episode 42 finished after 1063 steps with total reward 16.0
# Episode 43 finished after 1086 steps with total reward 23.0
# Episode 44 finished after 1100 steps with total reward 14.0
# Episode 45 finished after 1111 steps with total reward 11.0
# Episode 46 finished after 1124 steps with total reward 13.0
# Episode 47 finished after 1174 steps with total reward 50.0
# Episode 48 finished after 1254 steps with total reward 80.0
# Episode 49 finished after 1268 steps with total reward 14.0
# Episode 50 finished after 1280 steps with total reward 12.0
# Episode 51 finished after 1330 steps with total reward 50.0
# Episode 52 finished after 1342 steps with total reward 12.0
# Episode 53 finished after 1367 steps with total reward 25.0
# Episode 54 finished after 1385 steps with total reward 18.0
# Episode 55 finished after 1409 steps with total reward 24.0
# Episode 56 finished after 1423 steps with total reward 14.0
# Episode 57 finished after 1447 steps with total reward 24.0
# Episode 58 finished after 1462 steps with total reward 15.0
# Episode 59 finished after 1497 steps with total reward 35.0
# Episode 60 finished after 1524 steps with total reward 27.0
# Episode 61 finished after 1548 steps with total reward 24.0
# Episode 62 finished after 1577 steps with total reward 29.0
# Episode 63 finished after 1595 steps with total reward 18.0
# Episode 64 finished after 1616 steps with total reward 21.0
# Episode 65 finished after 1629 steps with total reward 13.0
# Episode 66 finished after 1650 steps with total reward 21.0
# Episode 67 finished after 1670 steps with total reward 20.0
# Episode 68 finished after 1683 steps with total reward 13.0
# Episode 69 finished after 1706 steps with total reward 23.0
# Episode 70 finished after 1739 steps with total reward 33.0
# Episode 71 finished after 1763 steps with total reward 24.0
# Episode 72 finished after 1784 steps with total reward 21.0
# Episode 73 finished after 1799 steps with total reward 15.0
# Episode 74 finished after 1812 steps with total reward 13.0
# Episode 75 finished after 1824 steps with total reward 12.0
# Episode 76 finished after 1866 steps with total reward 42.0
# Episode 77 finished after 1882 steps with total reward 16.0
# Episode 78 finished after 1895 steps with total reward 13.0
# Episode 79 finished after 1907 steps with total reward 12.0
# Episode 80 finished after 1984 steps with total reward 77.0
# Episode 81 finished after 2018 steps with total reward 34.0
# Episode 82 finished after 2034 steps with total reward 16.0
# Episode 83 finished after 2061 steps with total reward 27.0
# Episode 84 finished after 2100 steps with total reward 39.0
# Episode 85 finished after 2131 steps with total reward 31.0
# Episode 86 finished after 2166 steps with total reward 35.0
# Episode 87 finished after 2199 steps with total reward 33.0
# Episode 88 finished after 2230 steps with total reward 31.0
# Episode 89 finished after 2262 steps with total reward 32.0
# Episode 90 finished after 2288 steps with total reward 26.0
# Episode 91 finished after 2331 steps with total reward 43.0
# Episode 92 finished after 2347 steps with total reward 16.0
# Episode 93 finished after 2375 steps with total reward 28.0
# Episode 94 finished after 2389 steps with total reward 14.0
# Episode 95 finished after 2431 steps with total reward 42.0
# Episode 96 finished after 2475 steps with total reward 44.0
# Episode 97 finished after 2485 steps with total reward 10.0
# Episode 98 finished after 2500 steps with total reward 15.0
# Episode 99 finished after 2523 steps with total reward 23.0
# Episode 100 finished after 2532 steps with total reward 9.0
# Episode 101 finished after 2572 steps with total reward 40.0
# Episode 102 finished after 2605 steps with total reward 33.0
# Episode 103 finished after 2628 steps with total reward 23.0
# Episode 104 finished after 2650 steps with total reward 22.0
# Episode 105 finished after 2673 steps with total reward 23.0
# Episode 106 finished after 2693 steps with total reward 20.0
# Episode 107 finished after 2718 steps with total reward 25.0
# Episode 108 finished after 2727 steps with total reward 9.0
# Episode 109 finished after 2764 steps with total reward 37.0
# Episode 110 finished after 2799 steps with total reward 35.0
# Episode 111 finished after 2869 steps with total reward 70.0
# Episode 112 finished after 2899 steps with total reward 30.0
# Episode 113 finished after 2924 steps with total reward 25.0
# Episode 114 finished after 2952 steps with total reward 28.0
# Episode 115 finished after 2967 steps with total reward 15.0
# Episode 116 finished after 2981 steps with total reward 14.0
# Episode 117 finished after 3038 steps with total reward 57.0
# Episode 118 finished after 3077 steps with total reward 39.0
# Episode 119 finished after 3118 steps with total reward 41.0
# Episode 120 finished after 3133 steps with total reward 15.0
# Episode 121 finished after 3153 steps with total reward 20.0
# Episode 122 finished after 3166 steps with total reward 13.0
# Episode 123 finished after 3183 steps with total reward 17.0
# Episode 124 finished after 3226 steps with total reward 43.0
# Episode 125 finished after 3237 steps with total reward 11.0
# Episode 126 finished after 3309 steps with total reward 72.0
# Episode 127 finished after 3329 steps with total reward 20.0
# Episode 128 finished after 3355 steps with total reward 26.0
# Episode 129 finished after 3424 steps with total reward 69.0
# Episode 130 finished after 3446 steps with total reward 22.0
# Episode 131 finished after 3495 steps with total reward 49.0
# Episode 132 finished after 3521 steps with total reward 26.0
# Episode 133 finished after 3533 steps with total reward 12.0
# Episode 134 finished after 3553 steps with total reward 20.0
# Episode 135 finished after 3588 steps with total reward 35.0
# Episode 136 finished after 3605 steps with total reward 17.0
# Episode 137 finished after 3625 steps with total reward 20.0
# Episode 138 finished after 3650 steps with total reward 25.0
# Episode 139 finished after 3690 steps with total reward 40.0
# Episode 140 finished after 3701 steps with total reward 11.0
# Episode 141 finished after 3728 steps with total reward 27.0
# Episode 142 finished after 3745 steps with total reward 17.0
# Episode 143 finished after 3760 steps with total reward 15.0
# Episode 144 finished after 3794 steps with total reward 34.0
# Episode 145 finished after 3812 steps with total reward 18.0
# Episode 146 finished after 3827 steps with total reward 15.0
# Episode 147 finished after 3841 steps with total reward 14.0
# Episode 148 finished after 3855 steps with total reward 14.0
# Episode 149 finished after 3890 steps with total reward 35.0
# Episode 150 finished after 3905 steps with total reward 15.0
# Episode 151 finished after 3921 steps with total reward 16.0
# Episode 152 finished after 3983 steps with total reward 62.0
# Episode 153 finished after 3999 steps with total reward 16.0
# Episode 154 finished after 4024 steps with total reward 25.0
# Episode 155 finished after 4058 steps with total reward 34.0
# Episode 156 finished after 4093 steps with total reward 35.0
# Episode 157 finished after 4119 steps with total reward 26.0
# Episode 158 finished after 4137 steps with total reward 18.0
# Episode 159 finished after 4148 steps with total reward 11.0
# Episode 160 finished after 4163 steps with total reward 15.0
# Episode 161 finished after 4179 steps with total reward 16.0
# Episode 162 finished after 4191 steps with total reward 12.0
# Episode 163 finished after 4202 steps with total reward 11.0
# Episode 164 finished after 4214 steps with total reward 12.0
# Episode 165 finished after 4240 steps with total reward 26.0
# Episode 166 finished after 4265 steps with total reward 25.0
# Episode 167 finished after 4278 steps with total reward 13.0
# Episode 168 finished after 4297 steps with total reward 19.0
# Episode 169 finished after 4314 steps with total reward 17.0
# Episode 170 finished after 4334 steps with total reward 20.0
# Episode 171 finished after 4383 steps with total reward 49.0
# Episode 172 finished after 4407 steps with total reward 24.0
# Episode 173 finished after 4439 steps with total reward 32.0
# Episode 174 finished after 4476 steps with total reward 37.0
# Episode 175 finished after 4498 steps with total reward 22.0
# Episode 176 finished after 4516 steps with total reward 18.0
# Episode 177 finished after 4532 steps with total reward 16.0
# Episode 178 finished after 4565 steps with total reward 33.0
# Episode 179 finished after 4582 steps with total reward 17.0
# Episode 180 finished after 4594 steps with total reward 12.0
# Episode 181 finished after 4617 steps with total reward 23.0
# Episode 182 finished after 4638 steps with total reward 21.0
# Episode 183 finished after 4663 steps with total reward 25.0
# Episode 184 finished after 4678 steps with total reward 15.0
# Episode 185 finished after 4698 steps with total reward 20.0
# Episode 186 finished after 4715 steps with total reward 17.0
# Episode 187 finished after 4762 steps with total reward 47.0
# Episode 188 finished after 4794 steps with total reward 32.0
# Episode 189 finished after 4811 steps with total reward 17.0
# Episode 190 finished after 4827 steps with total reward 16.0
# Episode 191 finished after 4845 steps with total reward 18.0
# Episode 192 finished after 4856 steps with total reward 11.0
# Episode 193 finished after 4872 steps with total reward 16.0
# Episode 194 finished after 4890 steps with total reward 18.0
# Episode 195 finished after 4915 steps with total reward 25.0
# Episode 196 finished after 4937 steps with total reward 22.0
# Episode 197 finished after 4964 steps with total reward 27.0
# Episode 198 finished after 4977 steps with total reward 13.0
# Episode 199 finished after 5009 steps with total reward 32.0
# Episode 200 finished after 5066 steps with total reward 57.0
# Episode 201 finished after 5094 steps with total reward 28.0
# Episode 202 finished after 5115 steps with total reward 21.0
# Episode 203 finished after 5137 steps with total reward 22.0
# Episode 204 finished after 5151 steps with total reward 14.0
# Episode 205 finished after 5215 steps with total reward 64.0
# Episode 206 finished after 5256 steps with total reward 41.0
# Episode 207 finished after 5285 steps with total reward 29.0
# Episode 208 finished after 5343 steps with total reward 58.0
# Episode 209 finished after 5355 steps with total reward 12.0
# Episode 210 finished after 5379 steps with total reward 24.0
# Episode 211 finished after 5396 steps with total reward 17.0
# Episode 212 finished after 5416 steps with total reward 20.0
# Episode 213 finished after 5444 steps with total reward 28.0
# Episode 214 finished after 5488 steps with total reward 44.0
# Episode 215 finished after 5521 steps with total reward 33.0
# Episode 216 finished after 5545 steps with total reward 24.0
# Episode 217 finished after 5561 steps with total reward 16.0
# Episode 218 finished after 5583 steps with total reward 22.0
# Episode 219 finished after 5597 steps with total reward 14.0
# Episode 220 finished after 5610 steps with total reward 13.0
# Episode 221 finished after 5635 steps with total reward 25.0
# Episode 222 finished after 5685 steps with total reward 50.0
# Episode 223 finished after 5698 steps with total reward 13.0
# Episode 224 finished after 5709 steps with total reward 11.0
# Episode 225 finished after 5728 steps with total reward 19.0
# Episode 226 finished after 5751 steps with total reward 23.0
# Episode 227 finished after 5770 steps with total reward 19.0
# Episode 228 finished after 5791 steps with total reward 21.0
# Episode 229 finished after 5837 steps with total reward 46.0
# Episode 230 finished after 5892 steps with total reward 55.0
# Episode 231 finished after 5904 steps with total reward 12.0
# Episode 232 finished after 5929 steps with total reward 25.0
# Episode 233 finished after 5954 steps with total reward 25.0
# Episode 234 finished after 5971 steps with total reward 17.0
# Episode 235 finished after 6000 steps with total reward 29.0
# Episode 236 finished after 6031 steps with total reward 31.0
# Episode 237 finished after 6100 steps with total reward 69.0
# Episode 238 finished after 6112 steps with total reward 12.0
# Episode 239 finished after 6137 steps with total reward 25.0
# Episode 240 finished after 6167 steps with total reward 30.0
# Episode 241 finished after 6194 steps with total reward 27.0
# Episode 242 finished after 6213 steps with total reward 19.0
# Episode 243 finished after 6231 steps with total reward 18.0
# Episode 244 finished after 6254 steps with total reward 23.0
# Episode 245 finished after 6266 steps with total reward 12.0
# Episode 246 finished after 6280 steps with total reward 14.0
# Episode 247 finished after 6305 steps with total reward 25.0
# Episode 248 finished after 6327 steps with total reward 22.0
# Episode 249 finished after 6340 steps with total reward 13.0
# Episode 250 finished after 6351 steps with total reward 11.0
# Episode 251 finished after 6379 steps with total reward 28.0
# Episode 252 finished after 6416 steps with total reward 37.0
# Episode 253 finished after 6434 steps with total reward 18.0
# Episode 254 finished after 6450 steps with total reward 16.0
# Episode 255 finished after 6465 steps with total reward 15.0
# Episode 256 finished after 6478 steps with total reward 13.0
# Episode 257 finished after 6496 steps with total reward 18.0
# Episode 258 finished after 6540 steps with total reward 44.0
# Episode 259 finished after 6562 steps with total reward 22.0
# Episode 260 finished after 6583 steps with total reward 21.0
# Episode 261 finished after 6619 steps with total reward 36.0
# Episode 262 finished after 6635 steps with total reward 16.0
# Episode 263 finished after 6659 steps with total reward 24.0
# Episode 264 finished after 6677 steps with total reward 18.0
# Episode 265 finished after 6688 steps with total reward 11.0
# Episode 266 finished after 6702 steps with total reward 14.0
# Episode 267 finished after 6793 steps with total reward 91.0
# Episode 268 finished after 6810 steps with total reward 17.0
# Episode 269 finished after 6822 steps with total reward 12.0
# Episode 270 finished after 6855 steps with total reward 33.0
# Episode 271 finished after 6873 steps with total reward 18.0
# Episode 272 finished after 6888 steps with total reward 15.0
# Episode 273 finished after 6904 steps with total reward 16.0
# Episode 274 finished after 6916 steps with total reward 12.0
# Episode 275 finished after 6987 steps with total reward 71.0
# Episode 276 finished after 7009 steps with total reward 22.0
# Episode 277 finished after 7051 steps with total reward 42.0
# Episode 278 finished after 7101 steps with total reward 50.0
# Episode 279 finished after 7137 steps with total reward 36.0
# Episode 280 finished after 7151 steps with total reward 14.0
# Episode 281 finished after 7178 steps with total reward 27.0
# Episode 282 finished after 7217 steps with total reward 39.0
# Episode 283 finished after 7227 steps with total reward 10.0
# Episode 284 finished after 7311 steps with total reward 84.0
# Episode 285 finished after 7327 steps with total reward 16.0
# Episode 286 finished after 7362 steps with total reward 35.0
# Episode 287 finished after 7390 steps with total reward 28.0
# Episode 288 finished after 7414 steps with total reward 24.0
# Episode 289 finished after 7434 steps with total reward 20.0
# Episode 290 finished after 7473 steps with total reward 39.0
# Episode 291 finished after 7502 steps with total reward 29.0
# Episode 292 finished after 7520 steps with total reward 18.0
# Episode 293 finished after 7543 steps with total reward 23.0
# Episode 294 finished after 7561 steps with total reward 18.0
# Episode 295 finished after 7579 steps with total reward 18.0
# Episode 296 finished after 7614 steps with total reward 35.0
# Episode 297 finished after 7650 steps with total reward 36.0
# Episode 298 finished after 7670 steps with total reward 20.0
# Episode 299 finished after 7692 steps with total reward 22.0
# Episode 300 finished after 7706 steps with total reward 14.0
# Episode 301 finished after 7721 steps with total reward 15.0
# Episode 302 finished after 7740 steps with total reward 19.0
# Episode 303 finished after 7763 steps with total reward 23.0
# Episode 304 finished after 7797 steps with total reward 34.0
# Episode 305 finished after 7812 steps with total reward 15.0
# Episode 306 finished after 7833 steps with total reward 21.0
# Episode 307 finished after 7892 steps with total reward 59.0
# Episode 308 finished after 7911 steps with total reward 19.0
# Episode 309 finished after 7939 steps with total reward 28.0
# Episode 310 finished after 7956 steps with total reward 17.0
# Episode 311 finished after 7982 steps with total reward 26.0
# Episode 312 finished after 7993 steps with total reward 11.0
# Episode 313 finished after 8038 steps with total reward 45.0
# Episode 314 finished after 8048 steps with total reward 10.0
# Episode 315 finished after 8073 steps with total reward 25.0
# Episode 316 finished after 8088 steps with total reward 15.0
# Episode 317 finished after 8100 steps with total reward 12.0
# Episode 318 finished after 8121 steps with total reward 21.0
# Episode 319 finished after 8136 steps with total reward 15.0
# Episode 320 finished after 8155 steps with total reward 19.0
# Episode 321 finished after 8172 steps with total reward 17.0
# Episode 322 finished after 8229 steps with total reward 57.0
# Episode 323 finished after 8254 steps with total reward 25.0
# Episode 324 finished after 8273 steps with total reward 19.0
# Episode 325 finished after 8296 steps with total reward 23.0
# Episode 326 finished after 8320 steps with total reward 24.0
# Episode 327 finished after 8335 steps with total reward 15.0
# Episode 328 finished after 8369 steps with total reward 34.0
# Episode 329 finished after 8426 steps with total reward 57.0
# Episode 330 finished after 8448 steps with total reward 22.0
# Episode 331 finished after 8486 steps with total reward 38.0
# Episode 332 finished after 8512 steps with total reward 26.0
# Episode 333 finished after 8526 steps with total reward 14.0
# Episode 334 finished after 8541 steps with total reward 15.0
# Episode 335 finished after 8557 steps with total reward 16.0
# Episode 336 finished after 8577 steps with total reward 20.0
# Episode 337 finished after 8603 steps with total reward 26.0
# Episode 338 finished after 8649 steps with total reward 46.0
# Episode 339 finished after 8667 steps with total reward 18.0
# Episode 340 finished after 8690 steps with total reward 23.0
# Episode 341 finished after 8721 steps with total reward 31.0
# Episode 342 finished after 8733 steps with total reward 12.0
# Episode 343 finished after 8747 steps with total reward 14.0
# Episode 344 finished after 8771 steps with total reward 24.0
# Episode 345 finished after 8787 steps with total reward 16.0
# Episode 346 finished after 8812 steps with total reward 25.0
# Episode 347 finished after 8830 steps with total reward 18.0
# Episode 348 finished after 8845 steps with total reward 15.0
# Episode 349 finished after 8866 steps with total reward 21.0
# Episode 350 finished after 8923 steps with total reward 57.0
# Episode 351 finished after 8944 steps with total reward 21.0
# Episode 352 finished after 8962 steps with total reward 18.0
# Episode 353 finished after 8995 steps with total reward 33.0
# Episode 354 finished after 9012 steps with total reward 17.0
# Episode 355 finished after 9033 steps with total reward 21.0
# Episode 356 finished after 9052 steps with total reward 19.0
# Episode 357 finished after 9068 steps with total reward 16.0
# Episode 358 finished after 9089 steps with total reward 21.0
# Episode 359 finished after 9114 steps with total reward 25.0
# Episode 360 finished after 9140 steps with total reward 26.0
# Episode 361 finished after 9197 steps with total reward 57.0
# Episode 362 finished after 9246 steps with total reward 49.0
# Episode 363 finished after 9264 steps with total reward 18.0
# Episode 364 finished after 9306 steps with total reward 42.0
# Episode 365 finished after 9328 steps with total reward 22.0
# Episode 366 finished after 9358 steps with total reward 30.0
# Episode 367 finished after 9381 steps with total reward 23.0
# Episode 368 finished after 9402 steps with total reward 21.0
# Episode 369 finished after 9447 steps with total reward 45.0
# Episode 370 finished after 9457 steps with total reward 10.0
# Episode 371 finished after 9478 steps with total reward 21.0
# Episode 372 finished after 9532 steps with total reward 54.0
# Episode 373 finished after 9562 steps with total reward 30.0
# Episode 374 finished after 9574 steps with total reward 12.0
# Episode 375 finished after 9598 steps with total reward 24.0
# Episode 376 finished after 9653 steps with total reward 55.0
# Episode 377 finished after 9669 steps with total reward 16.0
# Episode 378 finished after 9685 steps with total reward 16.0
# Episode 379 finished after 9709 steps with total reward 24.0
# Episode 380 finished after 9766 steps with total reward 57.0
# Episode 381 finished after 9778 steps with total reward 12.0
# Episode 382 finished after 9797 steps with total reward 19.0
# Episode 383 finished after 9814 steps with total reward 17.0
# Episode 384 finished after 9829 steps with total reward 15.0
# Episode 385 finished after 9847 steps with total reward 18.0
# Episode 386 finished after 9892 steps with total reward 45.0
# Episode 387 finished after 9920 steps with total reward 28.0
# Episode 388 finished after 9938 steps with total reward 18.0
# Episode 389 finished after 9980 steps with total reward 42.0
# Episode 390 finished after 10010 steps with total reward 30.0
# Episode 391 finished after 10023 steps with total reward 13.0
# Episode 392 finished after 10043 steps with total reward 20.0
# Episode 393 finished after 10055 steps with total reward 12.0
# Episode 394 finished after 10072 steps with total reward 17.0
# Episode 395 finished after 10143 steps with total reward 71.0
# Episode 396 finished after 10160 steps with total reward 17.0
# Episode 397 finished after 10172 steps with total reward 12.0
# Episode 398 finished after 10201 steps with total reward 29.0
# Episode 399 finished after 10210 steps with total reward 9.0
# Episode 400 finished after 10222 steps with total reward 12.0
# Episode 401 finished after 10254 steps with total reward 32.0
# Episode 402 finished after 10272 steps with total reward 18.0
# Episode 403 finished after 10286 steps with total reward 14.0
# Episode 404 finished after 10306 steps with total reward 20.0
# Episode 405 finished after 10338 steps with total reward 32.0
# Episode 406 finished after 10354 steps with total reward 16.0
# Episode 407 finished after 10374 steps with total reward 20.0
# Episode 408 finished after 10391 steps with total reward 17.0
# Episode 409 finished after 10416 steps with total reward 25.0
# Episode 410 finished after 10439 steps with total reward 23.0
# Episode 411 finished after 10449 steps with total reward 10.0
# Episode 412 finished after 10472 steps with total reward 23.0
# Episode 413 finished after 10512 steps with total reward 40.0
# Episode 414 finished after 10537 steps with total reward 25.0
# Episode 415 finished after 10556 steps with total reward 19.0
# Episode 416 finished after 10570 steps with total reward 14.0
# Episode 417 finished after 10622 steps with total reward 52.0
# Episode 418 finished after 10641 steps with total reward 19.0
# Episode 419 finished after 10654 steps with total reward 13.0
# Episode 420 finished after 10681 steps with total reward 27.0
# Episode 421 finished after 10697 steps with total reward 16.0
# Episode 422 finished after 10725 steps with total reward 28.0
# Episode 423 finished after 10739 steps with total reward 14.0
# Episode 424 finished after 10770 steps with total reward 31.0
# Episode 425 finished after 10790 steps with total reward 20.0
# Episode 426 finished after 10815 steps with total reward 25.0
# Episode 427 finished after 10830 steps with total reward 15.0
# Episode 428 finished after 10863 steps with total reward 33.0
# Episode 429 finished after 10883 steps with total reward 20.0
# Episode 430 finished after 10913 steps with total reward 30.0
# Episode 431 finished after 10946 steps with total reward 33.0
# Episode 432 finished after 10969 steps with total reward 23.0
# Episode 433 finished after 10993 steps with total reward 24.0
# Episode 434 finished after 11026 steps with total reward 33.0
# Episode 435 finished after 11060 steps with total reward 34.0
# Episode 436 finished after 11078 steps with total reward 18.0
# Episode 437 finished after 11088 steps with total reward 10.0
# Episode 438 finished after 11105 steps with total reward 17.0
# Episode 439 finished after 11129 steps with total reward 24.0
# Episode 440 finished after 11177 steps with total reward 48.0
# Episode 441 finished after 11208 steps with total reward 31.0
# Episode 442 finished after 11243 steps with total reward 35.0
# Episode 443 finished after 11259 steps with total reward 16.0
# Episode 444 finished after 11311 steps with total reward 52.0
# Episode 445 finished after 11326 steps with total reward 15.0
# Episode 446 finished after 11347 steps with total reward 21.0
# Episode 447 finished after 11374 steps with total reward 27.0
# Episode 448 finished after 11396 steps with total reward 22.0
# Episode 449 finished after 11418 steps with total reward 22.0
# Episode 450 finished after 11473 steps with total reward 55.0
# Episode 451 finished after 11496 steps with total reward 23.0
# Episode 452 finished after 11507 steps with total reward 11.0
# Episode 453 finished after 11565 steps with total reward 58.0
# Episode 454 finished after 11599 steps with total reward 34.0
# Episode 455 finished after 11669 steps with total reward 70.0
# Episode 456 finished after 11701 steps with total reward 32.0
# Episode 457 finished after 11722 steps with total reward 21.0
# Episode 458 finished after 11754 steps with total reward 32.0
# Episode 459 finished after 11772 steps with total reward 18.0
# Episode 460 finished after 11786 steps with total reward 14.0
# Episode 461 finished after 11803 steps with total reward 17.0
# Episode 462 finished after 11824 steps with total reward 21.0
# Episode 463 finished after 11848 steps with total reward 24.0
# Episode 464 finished after 11885 steps with total reward 37.0
# Episode 465 finished after 11923 steps with total reward 38.0
# Episode 466 finished after 11942 steps with total reward 19.0
# Episode 467 finished after 11958 steps with total reward 16.0
# Episode 468 finished after 11977 steps with total reward 19.0
# Episode 469 finished after 12001 steps with total reward 24.0
# Episode 470 finished after 12012 steps with total reward 11.0
# Episode 471 finished after 12071 steps with total reward 59.0
# Episode 472 finished after 12102 steps with total reward 31.0
# Episode 473 finished after 12145 steps with total reward 43.0
# Episode 474 finished after 12158 steps with total reward 13.0
# Episode 475 finished after 12179 steps with total reward 21.0
# Episode 476 finished after 12203 steps with total reward 24.0
# Episode 477 finished after 12225 steps with total reward 22.0
# Episode 478 finished after 12239 steps with total reward 14.0
# Episode 479 finished after 12264 steps with total reward 25.0
# Episode 480 finished after 12277 steps with total reward 13.0
# Episode 481 finished after 12292 steps with total reward 15.0
# Episode 482 finished after 12312 steps with total reward 20.0
# Episode 483 finished after 12377 steps with total reward 65.0
# Episode 484 finished after 12439 steps with total reward 62.0
# Episode 485 finished after 12471 steps with total reward 32.0
# Episode 486 finished after 12486 steps with total reward 15.0
# Episode 487 finished after 12521 steps with total reward 35.0
# Episode 488 finished after 12545 steps with total reward 24.0
# Episode 489 finished after 12573 steps with total reward 28.0
# Episode 490 finished after 12595 steps with total reward 22.0
# Episode 491 finished after 12619 steps with total reward 24.0
# Episode 492 finished after 12649 steps with total reward 30.0
# Episode 493 finished after 12673 steps with total reward 24.0
# Episode 494 finished after 12700 steps with total reward 27.0
# Episode 495 finished after 12726 steps with total reward 26.0
# Episode 496 finished after 12770 steps with total reward 44.0
# Episode 497 finished after 12800 steps with total reward 30.0
# Episode 498 finished after 12818 steps with total reward 18.0
# Episode 499 finished after 12837 steps with total reward 19.0
# Episode 500 finished after 12851 steps with total reward 14.0
# Episode 501 finished after 12889 steps with total reward 38.0
# Episode 502 finished after 12938 steps with total reward 49.0
# Episode 503 finished after 12954 steps with total reward 16.0
# Episode 504 finished after 12992 steps with total reward 38.0
# Episode 505 finished after 13010 steps with total reward 18.0
# Episode 506 finished after 13032 steps with total reward 22.0
# Episode 507 finished after 13074 steps with total reward 42.0
# Episode 508 finished after 13088 steps with total reward 14.0
# Episode 509 finished after 13113 steps with total reward 25.0
# Episode 510 finished after 13128 steps with total reward 15.0
# Episode 511 finished after 13148 steps with total reward 20.0
# Episode 512 finished after 13159 steps with total reward 11.0
# Episode 513 finished after 13175 steps with total reward 16.0
# Episode 514 finished after 13209 steps with total reward 34.0
# Episode 515 finished after 13222 steps with total reward 13.0
# Episode 516 finished after 13279 steps with total reward 57.0
# Episode 517 finished after 13299 steps with total reward 20.0
# Episode 518 finished after 13310 steps with total reward 11.0
# Episode 519 finished after 13336 steps with total reward 26.0
# Episode 520 finished after 13356 steps with total reward 20.0
# Episode 521 finished after 13397 steps with total reward 41.0
# Episode 522 finished after 13411 steps with total reward 14.0
# Episode 523 finished after 13424 steps with total reward 13.0
# Episode 524 finished after 13439 steps with total reward 15.0
# Episode 525 finished after 13490 steps with total reward 51.0
# Episode 526 finished after 13546 steps with total reward 56.0
# Episode 527 finished after 13567 steps with total reward 21.0
# Episode 528 finished after 13599 steps with total reward 32.0
# Episode 529 finished after 13631 steps with total reward 32.0
# Episode 530 finished after 13651 steps with total reward 20.0
# Episode 531 finished after 13669 steps with total reward 18.0
# Episode 532 finished after 13682 steps with total reward 13.0
# Episode 533 finished after 13703 steps with total reward 21.0
# Episode 534 finished after 13755 steps with total reward 52.0
# Episode 535 finished after 13781 steps with total reward 26.0
# Episode 536 finished after 13795 steps with total reward 14.0
# Episode 537 finished after 13814 steps with total reward 19.0
# Episode 538 finished after 13827 steps with total reward 13.0
# Episode 539 finished after 13848 steps with total reward 21.0
# Episode 540 finished after 13867 steps with total reward 19.0
# Episode 541 finished after 13894 steps with total reward 27.0
# Episode 542 finished after 13919 steps with total reward 25.0
# Episode 543 finished after 13939 steps with total reward 20.0
# Episode 544 finished after 13981 steps with total reward 42.0
# Episode 545 finished after 13993 steps with total reward 12.0
# Episode 546 finished after 14008 steps with total reward 15.0
# Episode 547 finished after 14038 steps with total reward 30.0
# Episode 548 finished after 14065 steps with total reward 27.0
# Episode 549 finished after 14077 steps with total reward 12.0
# Episode 550 finished after 14094 steps with total reward 17.0
# Episode 551 finished after 14109 steps with total reward 15.0
# Episode 552 finished after 14137 steps with total reward 28.0
# Episode 553 finished after 14156 steps with total reward 19.0
# Episode 554 finished after 14174 steps with total reward 18.0
# Episode 555 finished after 14188 steps with total reward 14.0
# Episode 556 finished after 14199 steps with total reward 11.0
# Episode 557 finished after 14217 steps with total reward 18.0
# Episode 558 finished after 14263 steps with total reward 46.0
# Episode 559 finished after 14276 steps with total reward 13.0
# Episode 560 finished after 14301 steps with total reward 25.0
# Episode 561 finished after 14312 steps with total reward 11.0
# Episode 562 finished after 14326 steps with total reward 14.0
# Episode 563 finished after 14338 steps with total reward 12.0
# Episode 564 finished after 14349 steps with total reward 11.0
# Episode 565 finished after 14358 steps with total reward 9.0
# Episode 566 finished after 14393 steps with total reward 35.0
# Episode 567 finished after 14415 steps with total reward 22.0
# Episode 568 finished after 14445 steps with total reward 30.0
# Episode 569 finished after 14461 steps with total reward 16.0
# Episode 570 finished after 14471 steps with total reward 10.0
# Episode 571 finished after 14494 steps with total reward 23.0
# Episode 572 finished after 14522 steps with total reward 28.0
# Episode 573 finished after 14545 steps with total reward 23.0
# Episode 574 finished after 14587 steps with total reward 42.0
# Episode 575 finished after 14614 steps with total reward 27.0
# Episode 576 finished after 14637 steps with total reward 23.0
# Episode 577 finished after 14664 steps with total reward 27.0
# Episode 578 finished after 14679 steps with total reward 15.0
# Episode 579 finished after 14695 steps with total reward 16.0
# Episode 580 finished after 14736 steps with total reward 41.0
# Episode 581 finished after 14752 steps with total reward 16.0
# Episode 582 finished after 14820 steps with total reward 68.0
# Episode 583 finished after 14837 steps with total reward 17.0
# Episode 584 finished after 14883 steps with total reward 46.0
# Episode 585 finished after 14902 steps with total reward 19.0
# Episode 586 finished after 14926 steps with total reward 24.0
# Episode 587 finished after 14942 steps with total reward 16.0
# Episode 588 finished after 14962 steps with total reward 20.0
# Episode 589 finished after 15004 steps with total reward 42.0
# Episode 590 finished after 15033 steps with total reward 29.0
# Episode 591 finished after 15063 steps with total reward 30.0
# Episode 592 finished after 15076 steps with total reward 13.0
# Episode 593 finished after 15097 steps with total reward 21.0
# Episode 594 finished after 15146 steps with total reward 49.0
# Episode 595 finished after 15157 steps with total reward 11.0
# Episode 596 finished after 15182 steps with total reward 25.0
# Episode 597 finished after 15196 steps with total reward 14.0
# Episode 598 finished after 15218 steps with total reward 22.0
# Episode 599 finished after 15228 steps with total reward 10.0
# Episode 600 finished after 15247 steps with total reward 19.0
# Episode 601 finished after 15297 steps with total reward 50.0
# Episode 602 finished after 15340 steps with total reward 43.0
# Episode 603 finished after 15355 steps with total reward 15.0
# Episode 604 finished after 15366 steps with total reward 11.0
# Episode 605 finished after 15388 steps with total reward 22.0
# Episode 606 finished after 15413 steps with total reward 25.0
# Episode 607 finished after 15438 steps with total reward 25.0
# Episode 608 finished after 15472 steps with total reward 34.0
# Episode 609 finished after 15491 steps with total reward 19.0
# Episode 610 finished after 15517 steps with total reward 26.0
# Episode 611 finished after 15556 steps with total reward 39.0
# Episode 612 finished after 15574 steps with total reward 18.0
# Episode 613 finished after 15601 steps with total reward 27.0
# Episode 614 finished after 15628 steps with total reward 27.0
# Episode 615 finished after 15654 steps with total reward 26.0
# Episode 616 finished after 15758 steps with total reward 104.0
# Episode 617 finished after 15776 steps with total reward 18.0
# Episode 618 finished after 15786 steps with total reward 10.0
# Episode 619 finished after 15819 steps with total reward 33.0
# Episode 620 finished after 15840 steps with total reward 21.0
# Episode 621 finished after 15867 steps with total reward 27.0
# Episode 622 finished after 15884 steps with total reward 17.0
# Episode 623 finished after 15901 steps with total reward 17.0
# Episode 624 finished after 15926 steps with total reward 25.0
# Episode 625 finished after 15947 steps with total reward 21.0
# Episode 626 finished after 15966 steps with total reward 19.0
# Episode 627 finished after 15980 steps with total reward 14.0
# Episode 628 finished after 16061 steps with total reward 81.0
# Episode 629 finished after 16090 steps with total reward 29.0
# Episode 630 finished after 16113 steps with total reward 23.0
# Episode 631 finished after 16128 steps with total reward 15.0
# Episode 632 finished after 16147 steps with total reward 19.0
# Episode 633 finished after 16159 steps with total reward 12.0
# Episode 634 finished after 16194 steps with total reward 35.0
# Episode 635 finished after 16222 steps with total reward 28.0
# Episode 636 finished after 16239 steps with total reward 17.0
# Episode 637 finished after 16257 steps with total reward 18.0
# Episode 638 finished after 16289 steps with total reward 32.0
# Episode 639 finished after 16305 steps with total reward 16.0
# Episode 640 finished after 16316 steps with total reward 11.0
# Episode 641 finished after 16362 steps with total reward 46.0
# Episode 642 finished after 16407 steps with total reward 45.0
# Episode 643 finished after 16426 steps with total reward 19.0
# Episode 644 finished after 16462 steps with total reward 36.0
# Episode 645 finished after 16481 steps with total reward 19.0
# Episode 646 finished after 16495 steps with total reward 14.0
# Episode 647 finished after 16511 steps with total reward 16.0
# Episode 648 finished after 16541 steps with total reward 30.0
# Episode 649 finished after 16551 steps with total reward 10.0
# Episode 650 finished after 16577 steps with total reward 26.0
# Episode 651 finished after 16633 steps with total reward 56.0
# Episode 652 finished after 16649 steps with total reward 16.0
# Episode 653 finished after 16668 steps with total reward 19.0
# Episode 654 finished after 16683 steps with total reward 15.0
# Episode 655 finished after 16705 steps with total reward 22.0
# Episode 656 finished after 16717 steps with total reward 12.0
# Episode 657 finished after 16754 steps with total reward 37.0
# Episode 658 finished after 16774 steps with total reward 20.0
# Episode 659 finished after 16794 steps with total reward 20.0
# Episode 660 finished after 16808 steps with total reward 14.0
# Episode 661 finished after 16836 steps with total reward 28.0
# Episode 662 finished after 16864 steps with total reward 28.0
# Episode 663 finished after 16889 steps with total reward 25.0
# Episode 664 finished after 16902 steps with total reward 13.0
# Episode 665 finished after 16941 steps with total reward 39.0
# Episode 666 finished after 16959 steps with total reward 18.0
# Episode 667 finished after 16983 steps with total reward 24.0
# Episode 668 finished after 17009 steps with total reward 26.0
# Episode 669 finished after 17021 steps with total reward 12.0
# Episode 670 finished after 17034 steps with total reward 13.0
# Episode 671 finished after 17051 steps with total reward 17.0
# Episode 672 finished after 17113 steps with total reward 62.0
# Episode 673 finished after 17132 steps with total reward 19.0
# Episode 674 finished after 17153 steps with total reward 21.0
# Episode 675 finished after 17171 steps with total reward 18.0
# Episode 676 finished after 17186 steps with total reward 15.0
# Episode 677 finished after 17216 steps with total reward 30.0
# Episode 678 finished after 17227 steps with total reward 11.0
# Episode 679 finished after 17251 steps with total reward 24.0
# Episode 680 finished after 17269 steps with total reward 18.0
# Episode 681 finished after 17279 steps with total reward 10.0
# Episode 682 finished after 17291 steps with total reward 12.0
# Episode 683 finished after 17310 steps with total reward 19.0
# Episode 684 finished after 17323 steps with total reward 13.0
# Episode 685 finished after 17340 steps with total reward 17.0
# Episode 686 finished after 17354 steps with total reward 14.0
# Episode 687 finished after 17376 steps with total reward 22.0
# Episode 688 finished after 17390 steps with total reward 14.0
# Episode 689 finished after 17432 steps with total reward 42.0
# Episode 690 finished after 17444 steps with total reward 12.0
# Episode 691 finished after 17458 steps with total reward 14.0
# Episode 692 finished after 17508 steps with total reward 50.0
# Episode 693 finished after 17535 steps with total reward 27.0
# Episode 694 finished after 17559 steps with total reward 24.0
# Episode 695 finished after 17590 steps with total reward 31.0
# Episode 696 finished after 17603 steps with total reward 13.0
# Episode 697 finished after 17648 steps with total reward 45.0
# Episode 698 finished after 17681 steps with total reward 33.0
# Episode 699 finished after 17699 steps with total reward 18.0
# Episode 700 finished after 17747 steps with total reward 48.0
# Episode 701 finished after 17768 steps with total reward 21.0
# Episode 702 finished after 17842 steps with total reward 74.0
# Episode 703 finished after 17882 steps with total reward 40.0
# Episode 704 finished after 17901 steps with total reward 19.0
# Episode 705 finished after 17916 steps with total reward 15.0
# Episode 706 finished after 17966 steps with total reward 50.0
# Episode 707 finished after 17980 steps with total reward 14.0
# Episode 708 finished after 18019 steps with total reward 39.0
# Episode 709 finished after 18074 steps with total reward 55.0
# Episode 710 finished after 18124 steps with total reward 50.0
# Episode 711 finished after 18152 steps with total reward 28.0
# Episode 712 finished after 18169 steps with total reward 17.0
# Episode 713 finished after 18202 steps with total reward 33.0
# Episode 714 finished after 18243 steps with total reward 41.0
# Episode 715 finished after 18255 steps with total reward 12.0
# Episode 716 finished after 18277 steps with total reward 22.0
# Episode 717 finished after 18325 steps with total reward 48.0
# Episode 718 finished after 18343 steps with total reward 18.0
# Episode 719 finished after 18364 steps with total reward 21.0
# Episode 720 finished after 18431 steps with total reward 67.0
# Episode 721 finished after 18463 steps with total reward 32.0
# Episode 722 finished after 18492 steps with total reward 29.0
# Episode 723 finished after 18524 steps with total reward 32.0
# Episode 724 finished after 18554 steps with total reward 30.0
# Episode 725 finished after 18575 steps with total reward 21.0
# Episode 726 finished after 18611 steps with total reward 36.0
# Episode 727 finished after 18644 steps with total reward 33.0
# Episode 728 finished after 18671 steps with total reward 27.0
# Episode 729 finished after 18697 steps with total reward 26.0
# Episode 730 finished after 18717 steps with total reward 20.0
# Episode 731 finished after 18731 steps with total reward 14.0
# Episode 732 finished after 18773 steps with total reward 42.0
# Episode 733 finished after 18787 steps with total reward 14.0
# Episode 734 finished after 18802 steps with total reward 15.0
# Episode 735 finished after 18816 steps with total reward 14.0
# Episode 736 finished after 18840 steps with total reward 24.0
# Episode 737 finished after 18877 steps with total reward 37.0
# Episode 738 finished after 18900 steps with total reward 23.0
# Episode 739 finished after 18914 steps with total reward 14.0
# Episode 740 finished after 18958 steps with total reward 44.0
# Episode 741 finished after 18972 steps with total reward 14.0
# Episode 742 finished after 18986 steps with total reward 14.0
# Episode 743 finished after 19007 steps with total reward 21.0
# Episode 744 finished after 19058 steps with total reward 51.0
# Episode 745 finished after 19080 steps with total reward 22.0
# Episode 746 finished after 19116 steps with total reward 36.0
# Episode 747 finished after 19127 steps with total reward 11.0
# Episode 748 finished after 19141 steps with total reward 14.0
# Episode 749 finished after 19159 steps with total reward 18.0
# Episode 750 finished after 19218 steps with total reward 59.0
# Episode 751 finished after 19231 steps with total reward 13.0
# Episode 752 finished after 19246 steps with total reward 15.0
# Episode 753 finished after 19296 steps with total reward 50.0
# Episode 754 finished after 19313 steps with total reward 17.0
# Episode 755 finished after 19327 steps with total reward 14.0
# Episode 756 finished after 19342 steps with total reward 15.0
# Episode 757 finished after 19354 steps with total reward 12.0
# Episode 758 finished after 19368 steps with total reward 14.0
# Episode 759 finished after 19388 steps with total reward 20.0
# Episode 760 finished after 19410 steps with total reward 22.0
# Episode 761 finished after 19424 steps with total reward 14.0
# Episode 762 finished after 19450 steps with total reward 26.0
# Episode 763 finished after 19458 steps with total reward 8.0
# Episode 764 finished after 19477 steps with total reward 19.0
# Episode 765 finished after 19495 steps with total reward 18.0
# Episode 766 finished after 19504 steps with total reward 9.0
# Episode 767 finished after 19519 steps with total reward 15.0
# Episode 768 finished after 19533 steps with total reward 14.0
# Episode 769 finished after 19556 steps with total reward 23.0
# Episode 770 finished after 19598 steps with total reward 42.0
# Episode 771 finished after 19644 steps with total reward 46.0
# Episode 772 finished after 19655 steps with total reward 11.0
# Episode 773 finished after 19679 steps with total reward 24.0
# Episode 774 finished after 19715 steps with total reward 36.0
# Episode 775 finished after 19742 steps with total reward 27.0
# Episode 776 finished after 19795 steps with total reward 53.0
# Episode 777 finished after 19824 steps with total reward 29.0
# Episode 778 finished after 19853 steps with total reward 29.0
# Episode 779 finished after 19881 steps with total reward 28.0
# Episode 780 finished after 19899 steps with total reward 18.0
# Episode 781 finished after 19936 steps with total reward 37.0
# Episode 782 finished after 19954 steps with total reward 18.0
